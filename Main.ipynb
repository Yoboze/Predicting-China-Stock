# %%
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import metrics
from utils import *
from model import *

data1 = pd.read_csv("./601988.SH.csv")
data1.index = pd.to_datetime(data1['trade_date'], format='%Y%m%d')
#data1 = data1.drop(['ts_code', 'trade_date', 'turnover_rate', 'volume_ratio', 'pb', 'total_share', 'float_share', 'free_share'], axis=1)
data1 = data1.loc[:, ['open', 'high', 'low', 'close', 'vol', 'amount']]
data_yuan = data1
residuals = pd.read_csv('./ARIMA_residuals1.csv')
residuals.index = pd.to_datetime(residuals['trade_date'])
residuals.pop('trade_date')
data1 = pd.merge(data1, residuals, on='trade_date')
data = data1.iloc[1:3500, :] 
data2 = data1.iloc[3500:, :] 

TIME_STEPS = 20

data, normalize = NormalizeMult(data)
print('#', normalize)
pollution_data = data[:, 3].reshape(len(data), 1)

train_X, _ = create_dataset(data, TIME_STEPS)
_, train_Y = create_dataset(pollution_data, TIME_STEPS)

print(train_X.shape, train_Y.shape)

m = attention_model(INPUT_DIMS=7)
m.summary() 
adam = Adam(learning_rate=0.01)
m.compile(optimizer=adam, loss='mse') 
history = m.fit([train_X], train_Y, epochs=50, batch_size=32, validation_split=0.1)
m.save("./stock_model.h5")
np.save("stock_normalize.npy", normalize)
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# normalize = np.load("normalize.npy")
# loadmodelname = "model.h5"

class Config:
    def __init__(self):
        self.dimname = 'close'

config = Config()
name = config.dimname
# normalize = np.load("normalize.npy")
y_hat, y_test = PredictWithData(data2, data_yuan, name, 'stock_model.h5',7)
y_hat = np.array(y_hat, dtype='float64')
y_test = np.array(y_test, dtype='float64')
evaluation_metric(y_test,y_hat)
time = pd.Series(data1.index[3499:])
plt.figure(figsize=(10, 6))
plt.plot(time[:181], y_test, label='True')
plt.plot(time[:181], y_hat, label='Prediction')
plt.title('Hybrid model prediction')
plt.xlabel('Time', fontsize=12, verticalalignment='top')
plt.ylabel('Price', fontsize=14, horizontalalignment='center')
plt.legend()
plt.show()
# Out:
# (7, 2)
# # [[ 2.46000000e+00  7.40000000e+00]
#  [ 2.46000000e+00  7.58000000e+00]
#  [ 2.44000000e+00  7.23000000e+00]
#  [ 2.45000000e+00  7.48000000e+00]
#  [ 5.67951900e+04  5.10989742e+07]
#  [ 1.57377550e+04  2.74651219e+07]
#  [-5.59999999e-01  4.97357725e-01]]
# (3478, 20, 7) (3478, 1)
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 20, 7)]      0           []
#
#  conv1d_6 (Conv1D)              (None, 20, 64)       512         ['input_7[0][0]']
#
#  dropout_12 (Dropout)           (None, 20, 64)       0           ['conv1d_6[0][0]']
#
#  bidirectional_6 (Bidirectional  (None, 20, 128)     66048       ['dropout_12[0][0]']
#  )
#
#  dropout_13 (Dropout)           (None, 20, 128)      0           ['bidirectional_6[0][0]']
#
#  permute_12 (Permute)           (None, 128, 20)      0           ['dropout_13[0][0]']
#
#  dense_12 (Dense)               (None, 128, 20)      420         ['permute_12[0][0]']
#
#  permute_13 (Permute)           (None, 20, 128)      0           ['dense_12[0][0]']
#
#  multiply_6 (Multiply)          (None, 20, 128)      0           ['dropout_13[0][0]',
#                                                                   'permute_13[0][0]']
#
#  flatten_6 (Flatten)            (None, 2560)         0           ['multiply_6[0][0]']
#
#  dense_13 (Dense)               (None, 1)            2561        ['flatten_6[0][0]']
#
# ==================================================================================================
# Total params: 69,541
# Trainable params: 69,541
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-10-21 12:42:17.119020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023
# Epoch 47/50
# 98/98 [==============================] - 1s 8ms/step - loss: 3.7669e-04 - val_loss: 5.9455e-05
# Epoch 48/50
# 98/98 [==============================] - 1s 8ms/step - loss: 3.3853e-04 - val_loss: 2.0768e-04
# Epoch 49/50
# 98/98 [==============================] - 1s 8ms/step - loss: 3.8997e-04 - val_loss: 5.9887e-05
# Epoch 50/50
# 98/98 [==============================] - 1s 8ms/step - loss: 3.5756e-04 - val_loss: 1.6790e-04
# Index(['open', 'high', 'low', 'close', 'vol', 'amount', '0'], dtype='object')
# (7, 2)
# testX Y shape is: (160, 20, 7) (160, 1)
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 20, 7)]      0           []
#
#  conv1d_7 (Conv1D)              (None, 20, 64)       512         ['input_8[0][0]']
#
#  dropout_14 (Dropout)           (None, 20, 64)       0           ['conv1d_7[0][0]']
#
#  bidirectional_7 (Bidirectional  (None, 20, 128)     66048       ['dropout_14[0][0]']
#  )
#
#  dropout_15 (Dropout)           (None, 20, 128)      0           ['bidirectional_7[0][0]']
#
#  permute_14 (Permute)           (None, 128, 20)      0           ['dropout_15[0][0]']
#
#  dense_14 (Dense)               (None, 128, 20)      420         ['permute_14[0][0]']
#
#  permute_15 (Permute)           (None, 20, 128)      0           ['dense_14[0][0]']
#
#  multiply_7 (Multiply)          (None, 20, 128)      0           ['dropout_15[0][0]',
#                                                                   'permute_15[0][0]']
#
#  flatten_7 (Flatten)            (None, 2560)         0           ['multiply_7[0][0]']
#
#  dense_15 (Dense)               (None, 1)            2561        ['flatten_7[0][0]']
#
# ==================================================================================================
# Total params: 69,541
# Trainable params: 69,541
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-10-21 12:42:59.247183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-21 12:42:59.248306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-21 12:42:59.249107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-21 12:42:59.337027: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-10-21 12:42:59.367824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-21 12:42:59.368560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-21 12:42:59.369267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-21 12:42:59.568294: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-21 12:42:59.569347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-21 12:42:59.570086: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-21 12:42:59.658392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-10-21 12:42:59.689332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-21 12:42:59.690088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-21 12:42:59.690813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 5/5 [==============================] - 0s 3ms/step
# supervised_data       var1(t-6)  var2(t-6)  var3(t-6)   var4(t-6)    var5(t-6)  var6(t-6)  \
# 6          5.69       5.97       5.37  7281333.33  4224852.614       5.63
# 7          5.30       5.34       5.07  7867306.84  4050377.943       5.07
# 8          4.87       5.14       4.83  5565756.49  2763751.983       5.08
# 9          5.06       5.19       4.95  4334458.33  2198327.249       5.18
# 10         5.25       5.29       5.05  3721171.25  1915221.182       5.10
# ...         ...        ...        ...         ...          ...        ...
# 3676       3.13       3.16       3.13  1374157.76   432082.360       3.15
# 3677       3.15       3.16       3.14  1560240.83   490908.221       3.15
# 3678       3.14       3.15       3.12  1360415.16   426283.660       3.13
# 3679       3.12       3.14       3.10  1500377.44   467690.817       3.10
# 3680       3.10       3.11       3.04  2660491.55   820162.507       3.08
#
#       var1(t-5)  var2(t-5)  var3(t-5)   var4(t-5)  ...  var3(t-1)   var4(t-1)  \
# 6          5.30       5.34       5.07  7867306.84  ...       4.90  3274026.49
# 7          4.87       5.14       4.83  5565756.49  ...       4.70  2329178.87
# 8          5.06       5.19       4.95  4334458.33  ...       4.65  2487325.37
# 9          5.25       5.29       5.05  3721171.25  ...       4.85  2595924.95
# 10         5.07       5.07       4.90  3274026.49  ...       4.82  2372504.49
# ...         ...        ...        ...         ...  ...        ...         ...
# 3676       3.15       3.16       3.14  1560240.83  ...       3.08  1101012.25
# 3677       3.14       3.15       3.12  1360415.16  ...       3.06  1789426.50
# 3678       3.12       3.14       3.10  1500377.44  ...       3.07  1576585.15
# 3679       3.10       3.11       3.04  2660491.55  ...       3.02  2902299.85
# 3680       3.09       3.10       3.08  1101012.25  ...       3.02  2194095.53
#
#         var5(t-1)  var6(t-1)  var1(t)  var2(t)  var3(t)     var4(t)  \
# 6     1625223.442       4.93     4.88     4.97     4.70  2329178.87
# 7     1126547.904       4.73     4.71     5.00     4.65  2487325.37
# 8     1200380.073       4.99     5.05     5.10     4.85  2595924.95
# 9     1286327.202       4.94     4.94     5.04     4.82  2372504.49
# 10    1166197.579       4.88     4.83     4.89     4.65  2036686.05
# ...           ...        ...      ...      ...      ...         ...
# 3676   339963.853       3.08     3.08     3.11     3.06  1789426.50
# 3677   550569.534       3.10     3.08     3.12     3.07  1576585.15
# 3678   489277.432       3.09     3.09     3.09     3.02  2902299.85
# 3679   886628.898       3.03     3.04     3.08     3.02  2194095.53
# 3680   668104.914       3.07     3.08     3.09     3.05  1987681.46
#
#           var5(t)  var6(t)
# 6     1126547.904     4.73
# 7     1200380.073     4.99
# 8     1286327.202     4.94
# 9     1166197.579     4.88
# 10     967241.970     4.76
# ...           ...      ...
# 3676   550569.534     3.10
# 3677   489277.432     3.09
# 3678   886628.898     3.03
# 3679   668104.914     3.07
# 3680   609118.280     3.06
#
# [3675 rows x 42 columns]
# 1 >expected=3.070000, predicted=3.066880
# 2 >expected=3.070000, predicted=3.064462
# 3 >expected=3.070000, predicted=3.072164
# 4 >expected=3.070000, predicted=3.073484
# 5 >expected=3.090000, predicted=3.074908
# 6 >expected=3.080000, predicted=3.105852
# 7 >expected=3.080000, predicted=3.071840
# 8 >expected=3.080000, predicted=3.070710
# 9 >expected=3.080000, predicted=3.068389
# 10 >expected=3.080000, predicted=3.075188
# 11 >expected=3.080000, predicted=3.083882
# 12 >expected=3.090000, predicted=3.084976
# 13 >expected=3.080000, predicted=3.080935
# 14 >expected=3.070000, predicted=3.065362
# 15 >expected=3.070000, predicted=3.066538
# 16 >expected=3.060000, predicted=3.066680
# 17 >expected=3.050000, predicted=3.064612
# 18 >expected=3.030000, predicted=3.039992
# 19 >expected=3.040000, predicted=3.030490
# 20 >expected=3.050000, predicted=3.037377
# 21 >expected=3.040000, predicted=3.040670
# 22 >expected=3.040000, predicted=3.028887
# 23 >expected=3.040000, predicted=3.030756
# 24 >expected=3.050000, predicted=3.029954
# 25 >expected=3.040000, predicted=3.037376
# 26 >expected=3.050000, predicted=3.034929
# 27 >expected=3.040000, predicted=3.043027
# 28 >expected=3.040000, predicted=3.026633
# 29 >expected=3.020000, predicted=3.034926
# 30 >expected=2.990000, predicted=3.002907
# 31 >expected=3.010000, predicted=3.001005
# 32 >expected=2.990000, predicted=3.004122
# 33 >expected=2.980000, predicted=2.970421
# 34 >expected=2.990000, predicted=2.973076
# 35 >expected=2.990000, predicted=2.986962
# 36 >expected=3.020000, predicted=3.003984
# 37 >expected=3.020000, predicted=3.023661
# 38 >expected=3.040000, predicted=3.025482
# 39 >expected=3.020000, predicted=3.035784
# 40 >expected=3.030000, predicted=3.021959
# 41 >expected=3.030000, predicted=3.034819
# 42 >expected=3.010000, predicted=3.021426
# 43 >expected=3.040000, predicted=3.025071
# 44 >expected=3.020000, predicted=3.022876
# 45 >expected=3.020000, predicted=3.026492
# 46 >expected=3.030000, predicted=3.026733
# 47 >expected=3.020000, predicted=3.034192
# 48 >expected=3.020000, predicted=3.022675
# 49 >expected=3.010000, predicted=3.005802
# 50 >expected=3.020000, predicted=3.007895
# 51 >expected=3.000000, predicted=3.009349
# 52 >expected=3.030000, predicted=3.023277
# 53 >expected=3.060000, predicted=3.037702
# 54 >expected=3.050000, predicted=3.042981
# 55 >expected=3.060000, predicted=3.065660
# 56 >expected=3.060000, predicted=3.065214
# 57 >expected=3.090000, predicted=3.077061
# 58 >expected=3.100000, predicted=3.102436
# 59 >expected=3.090000, predicted=3.087328
# 60 >expected=3.100000, predicted=3.112316
# 61 >expected=3.100000, predicted=3.106345
# 62 >expected=3.060000, predicted=3.079883
# 63 >expected=3.060000, predicted=3.054378
# 64 >expected=3.050000, predicted=3.059909
# 65 >expected=3.070000, predicted=3.066387
# 66 >expected=3.050000, predicted=3.045244
# 67 >expected=3.070000, predicted=3.064302
# 68 >expected=3.050000, predicted=3.066062
# 69 >expected=3.050000, predicted=3.044128
# 70 >expected=3.060000, predicted=3.060703
# 71 >expected=3.060000, predicted=3.060904
# 72 >expected=3.050000, predicted=3.045140
# 73 >expected=3.070000, predicted=3.066053
# 74 >expected=3.080000, predicted=3.093053
# 75 >expected=3.080000, predicted=3.086033
# 76 >expected=3.070000, predicted=3.071332
# 77 >expected=3.060000, predicted=3.074278
# 78 >expected=3.050000, predicted=3.065041
# 79 >expected=3.060000, predicted=3.061972
# 80 >expected=3.060000, predicted=3.066249
# 81 >expected=3.060000, predicted=3.065807
# 82 >expected=3.080000, predicted=3.064355
# 83 >expected=3.060000, predicted=3.066462
# 84 >expected=3.070000, predicted=3.063727
# 85 >expected=3.060000, predicted=3.068097
# 86 >expected=3.060000, predicted=3.064589
# 87 >expected=3.050000, predicted=3.043345
# 88 >expected=3.050000, predicted=3.044383
# 89 >expected=3.070000, predicted=3.062774
# 90 >expected=3.040000, predicted=3.064544
# 91 >expected=3.040000, predicted=3.044994
# 92 >expected=3.040000, predicted=3.044611
# 93 >expected=3.040000, predicted=3.042560
# 94 >expected=3.030000, predicted=3.037087
# 95 >expected=3.040000, predicted=3.035411
# 96 >expected=3.040000, predicted=3.036979
# 97 >expected=3.070000, predicted=3.061962
# 98 >expected=3.060000, predicted=3.060377
# 99 >expected=3.060000, predicted=3.041403
# 100 >expected=3.060000, predicted=3.066171
# 101 >expected=3.070000, predicted=3.065539
# 102 >expected=3.060000, predicted=3.065402
# 103 >expected=3.060000, predicted=3.061886
# 104 >expected=3.060000, predicted=3.064017
# 105 >expected=3.070000, predicted=3.063979
# 106 >expected=3.080000, predicted=3.068621
# 107 >expected=3.080000, predicted=3.065880
# 108 >expected=3.070000, predicted=3.067774
# 109 >expected=3.060000, predicted=3.063429
# 110 >expected=3.050000, predicted=3.044217
# 111 >expected=3.060000, predicted=3.043629
# 112 >expected=3.050000, predicted=3.043204
# 113 >expected=3.060000, predicted=3.044729
# 114 >expected=3.060000, predicted=3.061737
# 115 >expected=3.070000, predicted=3.055803
# 116 >expected=3.060000, predicted=3.067586
# 117 >expected=3.070000, predicted=3.067715
# 118 >expected=3.070000, predicted=3.062043
# 119 >expected=3.060000, predicted=3.061943
# 120 >expected=3.050000, predicted=3.061992
# 121 >expected=3.050000, predicted=3.061880
# 122 >expected=3.050000, predicted=3.060874
# 123 >expected=3.060000, predicted=3.060674
# 124 >expected=3.050000, predicted=3.058139
# 125 >expected=3.060000, predicted=3.060061
# 126 >expected=3.060000, predicted=3.060935
# 127 >expected=3.060000, predicted=3.058578
# 128 >expected=3.050000, predicted=3.061814
# 129 >expected=3.060000, predicted=3.058996
# 130 >expected=3.070000, predicted=3.059669
# 131 >expected=3.050000, predicted=3.061621
# 132 >expected=3.050000, predicted=3.061112
# 133 >expected=3.050000, predicted=3.059548
# 134 >expected=3.070000, predicted=3.060319
# 135 >expected=3.090000, predicted=3.080736
# 136 >expected=3.090000, predicted=3.114074
# 137 >expected=3.140000, predicted=3.126631
# 138 >expected=3.130000, predicted=3.121759
# 139 >expected=3.140000, predicted=3.126929
# 140 >expected=3.120000, predicted=3.127585
# 141 >expected=3.140000, predicted=3.127287
# 142 >expected=3.090000, predicted=3.121410
# 143 >expected=3.090000, predicted=3.094485
# 144 >expected=3.120000, predicted=3.105101
# 145 >expected=3.110000, predicted=3.107271
# 146 >expected=3.120000, predicted=3.106985
# 147 >expected=3.120000, predicted=3.115235
# 148 >expected=3.120000, predicted=3.114823
# 149 >expected=3.090000, predicted=3.108184
# 150 >expected=3.090000, predicted=3.087633
# 151 >expected=3.090000, predicted=3.092498
# 152 >expected=3.090000, predicted=3.093144
# 153 >expected=3.130000, predicted=3.122920
# 154 >expected=3.170000, predicted=3.148402
# 155 >expected=3.160000, predicted=3.170415
# 156 >expected=3.190000, predicted=3.176513
# 157 >expected=3.190000, predicted=3.180827
# 158 >expected=3.170000, predicted=3.173628
# 159 >expected=3.150000, predicted=3.180058
# 160 >expected=3.170000, predicted=3.179135
# 161 >expected=3.180000, predicted=3.179254
# 162 >expected=3.200000, predicted=3.181693
# 163 >expected=3.180000, predicted=3.184272
# 164 >expected=3.170000, predicted=3.180722
# 165 >expected=3.160000, predicted=3.179179
# 166 >expected=3.110000, predicted=3.122480
# 167 >expected=3.110000, predicted=3.120170
# 168 >expected=3.100000, predicted=3.119696
# 169 >expected=3.120000, predicted=3.118239
# 170 >expected=3.130000, predicted=3.122795
# 171 >expected=3.150000, predicted=3.136729
# 172 >expected=3.150000, predicted=3.163740
# 173 >expected=3.130000, predicted=3.133654
# 174 >expected=3.100000, predicted=3.117033
# 175 >expected=3.080000, predicted=3.066792
# 176 >expected=3.080000, predicted=3.086776
# 177 >expected=3.100000, predicted=3.081023
# 178 >expected=3.090000, predicted=3.093013
# 179 >expected=3.030000, predicted=3.053169
# 180 >expected=3.070000, predicted=3.051047
# 181 >expected=3.060000, predicted=3.071842
# MSE: 0.00012
# RMSE: 0.01089
# MAE: 0.00896
# R2: 0.93181
